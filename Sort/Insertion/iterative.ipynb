# %%
# Start pointer


# Min --> Max


def sort(numbers):
    for i in range(1, len(numbers)):
        for j in range(i):
            if numbers[i] < numbers[j]:
                first_number = numbers[i]
                del numbers[i]
                numbers.insert(j, first_number)
                break
    return numbers


def sort(numbers):
    for i in range(1, len(numbers)):
        first_number = numbers[i]
        j = i - 1
        while j >= 0 and numbers[j] > first_number:
            numbers[j + 1] = numbers[j]
            j -= 1
        numbers[j + 1] = first_number
    return numbers


def sort(numbers):
    for i in range(1, len(numbers)):
        first_number = numbers[i]
        hole = i
        while hole > 0 and numbers[hole - 1] > first_number:
            numbers[hole] = numbers[hole - 1]
            hole -= 1
        numbers[hole] = first_number
    return numbers


# Max --> Min


def sort(numbers):
    for i in range(1, len(numbers)):
        for j in range(i):
            if numbers[i] > numbers[j]:
                first_number = numbers[i]
                del numbers[i]
                numbers.insert(j, first_number)
                break
    return numbers


def sort(numbers):
    for i in range(1, len(numbers)):
        first_number = numbers[i]
        j = i - 1
        while j >= 0 and numbers[j] < first_number:
            numbers[j + 1] = numbers[j]
            j -= 1
        numbers[j + 1] = first_number
    return numbers


def sort(numbers):
    for i in range(1, len(numbers)):
        first_number = numbers[i]
        hole = i
        while hole > 0 and numbers[hole - 1] < first_number:
            numbers[hole] = numbers[hole - 1]
            hole -= 1
        numbers[hole] = first_number
    return numbers


# End pointer


# Min --> Max


def sort(numbers):
    for i in range(1, len(numbers)):
        i = len(numbers) - (i + 1)
        for j in range((i + 1), len(numbers))[::-1]:
            if numbers[i] > numbers[j]:
                numbers.insert(j + 1, numbers[i])
                del numbers[i]
                break
    return numbers


def sort(numbers):
    for i in range(1, len(numbers)):
        i = len(numbers) - (i + 1)
        first_number = numbers[i]
        hole = i
        while hole < (len(numbers) - 1) and first_number > numbers[hole + 1]:
            numbers[hole] = numbers[hole + 1]
            hole += 1
        numbers[hole] = first_number
        print(numbers)
    return numbers


def sort(numbers):
    for i in range(1, len(numbers)):
        i = len(numbers) - (i + 1)
        first_number = numbers[i]
        j = i + 1
        while j <= (len(numbers) - 1) and first_number > numbers[j]:
            numbers[j - 1] = numbers[j]
            j += 1
        numbers[j - 1] = first_number
    return numbers


# Max --> Min


def sort(numbers):
    for i in range(1, len(numbers)):
        i = len(numbers) - (i + 1)
        for j in range(i + 1, len(numbers))[::-1]:
            if numbers[i] < numbers[j]:
                numbers.insert(j + 1, numbers[i])
                del numbers[i]
                break
    return numbers


def sort(numbers):
    for i in range(1, len(numbers)):
        i = len(numbers) - (i + 1)
        first_number = numbers[i]
        hole = i
        while hole < (len(numbers) - 1) and first_number < numbers[hole + 1]:
            numbers[hole] = numbers[hole + 1]
            hole += 1
        numbers[hole] = first_number
    return numbers


def sort(numbers):
    for i in range(1, len(numbers)):
        i = len(numbers) - (i + 1)
        first_number = numbers[i]
        j = i + 1
        while j <= (len(numbers) - 1) and first_number < numbers[j]:
            numbers[j - 1] = numbers[j]
            j += 1
        numbers[j - 1] = first_number
    return numbers
