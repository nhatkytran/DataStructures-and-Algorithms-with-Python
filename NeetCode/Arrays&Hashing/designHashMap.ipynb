# %%
class MyHashMap:
    def __init__(self):
        self.hashmap = []

    def put(self, key: int, value: int) -> None:
        for pair in self.hashmap:
            if pair[0] == key:
                pair[1] = value
                return
        self.hashmap.append([key, value])

    def get(self, key: int) -> int:
        for pair in self.hashmap:
            if pair[0] == key:
                return pair[1]
        return -1

    def remove(self, key: int) -> None:
        for i in range(len(self.hashmap)):
            if self.hashmap[i][0] == key:
                del self.hashmap[i]
                return
            

class MyHashMap:
    def __init__(self):
        self.hashmap = [None] * 1000000

    def put(self, key, value):
        self.hashmap[key] = value

    def get(self, key):
        return self.hashmap[key] if self.hashmap[key] != None else -1
    
    def remove(self, key):
        self.hashmap[key] = None


'''
Using hashing function with Linked Lista and dealing with collisions
[
    linked list,
    linked list,
    ...
]
--> put --> delete key if it already exists --> add new Node as a head of a Linked List
'''
class LinkedList:
    def __init__(self):
        self.head = None

    class Node:
        def __init__(self, value):
            self.value = value
            self.next = None

    def see(self):
        linked_list = ''
        start = self.head
        while start:
            linked_list += f'{start.value} --> '
            start = start.next
        return linked_list

    def add(self, value):
        node = self.Node(value)
        if not self.head:
            self.head = node
        else:
            start = self.head
            while start.next:
                start = start.next
            start.next = node

    def add_new_head(self, value):
        next_node = self.head
        self.head = self.Node(value)
        self.head.next = next_node

    def get(self, value):
        pass

    def remove(self, value):
        pass


# s = MyHashMap()
linked_list = LinkedList()

linked_list.add_new_head(1)
linked_list.add_new_head(2)
linked_list.add_new_head(3)

print(linked_list.see())
# Out:
# 3 --> 2 --> 1 -->
