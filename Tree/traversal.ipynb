# %%
#       0
#     /   \
#    1     2
#  /  \      \
# 3    4       5


class NodeTree:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


node0 = NodeTree(0)
node1 = NodeTree(1)
node2 = NodeTree(2)
node3 = NodeTree(3)
node4 = NodeTree(4)
node5 = NodeTree(5)

node0.left = node1
node0.right = node2
node1.left = node3
node1.right = node4
node2.right = node5


# Inorder

def recursive(root):
    if not root:
        return []
    return [*recursive(root.left), root.value, *recursive(root.right)]


def visit(root):
    result = []
    stack = [(root, False)]
    while stack:
        node, visited = stack.pop()
        if node:
            if visited:
                result.append(node.value)
            else:
                stack.append((node.right, False))
                stack.append((node, True))
                stack.append((node.left, False))
    return result


def special(root):
    result = []
    stack = []
    current = root
    while current or stack:
        while current:
            stack.append(current)
            current = current.left
        current = stack.pop()
        result.append(current.value)
        current = current.right
    return result


# Preorder

def recursive(root):
    if not root:
        return []
    return [root.value, *recursive(root.left), *recursive(root.right)]


def normal(root):
    result = []
    stack = [root]
    while stack:
        node = stack.pop()
        result.append(node.value)
        if node.right:
            stack.append(node.right)
        if node.left:
            stack.append(node.left)
    return result


def visit(root):
    result = []
    stack = [(root, False)]
    while stack:
        node, visited = stack.pop()
        if node:
            if visited:
                result.append(node.value)
            else:
                stack.append((node.right, False))
                stack.append((node.left, False))
                stack.append((node, True))
    return result


def special(root):
    result = []
    stack = []
    current = root
    while current or stack:
        if current:
            result.append(current.value)
            stack.append(current.right)
            current = current.left
        else:
            current = stack.pop()
    return result


# Postorder

def recursive(root):
    if not root:
        return []
    return [*recursive(root.left), *recursive(root.right), root.value]


def visit(root):
    result = []
    stack = [(root, False)]
    while stack:
        node, visited = stack.pop()
        if node:
            if visited:
                result.append(node.value)
            else:
                stack.append((node, True))
                stack.append((node.right, False))
                stack.append((node.left, False))
    return result


print(recursive(node0))
# Out:
# [3, 4, 1, 5, 2, 0]

# %%
def traverse_iterative(root):
    stack = []
    current = root
    result = []
    while current or stack:
        while current:
            stack.append(current)
            current = current.left
        current = stack.pop()
        result.append(current.value)
        current = current.right
    return result


print(traverse_iterative(node0))
# Out:
# [3, 1, 4, 0, 2, 5]
